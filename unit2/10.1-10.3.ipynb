# %%
import pandas as pd
df = pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#1.1 df_rows_count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
#1.1 df_rows_count
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
#1.1 df_rows_count
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
#1.2 max_total_bill
print(df.total_bill.max())
# Out:
# 50.81

# %%
# %matplotlib inline

# %%
df.plot()

# %%
df['total_bill'].plot(kind='hist', grid=True, title='Общая сумма счета')

# %%
df['day'].value_counts().plot(kind='bar', colormap='coolwarm', title='Количество посетителей по дням')

# %%
df.groupby(['sex','smoker'])['tip'].mean().plot(kind='bar', grid=True, title='Средние чаевые по полу и курению')

# %%
df[['total_bill', 'tip']].plot(subplots=True,kind='hist',title=['Общая сумма чаевых','Сумма чаевых'],legend=True,grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002561FF2A748>,
# ...
#       dtype=object)

# %%
df.plot(x='total_bill',y='tip',kind='scatter')

# %%
# df.groupby('day')['total_bill','tip'].mean().plot(kind='bar')
df.pivot_table(values=['total_bill','tip'],aggfunc='mean',index='day').plot(kind='bar')

# %%
#3.1 Количество клиентов по полу и отношению к курению
df.pivot_table(values = 'tip', index = ['sex', 'smoker'], aggfunc = 'count').plot(kind = 'bar')

# %%
#3.2 Средняя сумма чаевых курящих и не курящих клиентов
df.groupby('smoker')['tip'].mean().plot(kind='bar')
